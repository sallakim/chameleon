# %% [markdown]
# # Advanced model fitting: calibrating the MONARCH model
#
# ## Introduction
# The goal of this notebook is to calibrate our lab's MONARCH model to a synthetic data set, as published in Jones & Oomen [1]. We will generate a synthetic data set using MONARCH and calibrate the model to this synthetic data using CHAMLEON to check if we can recapitulate the known model parameters. We will calibrate a single heart beat simulation as well as a growth simulation. The outline will be:
# 1. Generating the synthetic data
# 2. Fitting the baseline model
# 3. Fitting the chronic model

# %%
# Enable automatically reloading modules when they have changed
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# When rerunning this notebook, set the run_sims variable to false to skip the simulation step and only run the GPEs and implausibility calculations. Simulations ran previously will be loaded and this will tremendously speed up the process.

# %%
import pathlib

main_dir = pathlib.Path.cwd() / "demo_monarch"
run_sims = True

# %% [markdown]
# ## Generating the synthetic data
# ### Running simulation
# The MONARCH model platform is a system of ordinary differential equations (ODEs) that describes cardiac physiology, mechanics and growth. The model is described in detail in [1]. First, import the model and initialize it with the default parameters from an input file designed to simulate volume overload in canines (from MONARCH's GitHub repository).

# %%
from monarch import Hatch

# Initialize model
input_vo = "P21_Hx_M"
beats = Hatch(input_vo)

# %% [markdown]
# We want to set a few constants to ensure a realistic wall geometry of all ventricles at all times. This is important because we only want to fit the LV parameters in this case, and want to have realistic geometries for the other chambers for every chosen parameter set. These constants include a ratio of midwall reference areas takes from [2], and the wall thicknesses of all other chambers than the LV at end-diastole from [3].

# %%
#model_constants = {"LfWth": 1.7, "RfWth": 0.85, "LAWth": 0.85, "RAWth": 0.85, "SWth": 1.7,
#                   "ratio_amref_lfw": 0.66, "ratio_amref_ww": 0.33, "ratio_amref_la": 0.46, "ratio_amref_ra": 0.34,
#                   "ratio_v_lfw": 2.05, "ratio_v_ww": 1.25, "ratio_v_la": 0.1894, "ratio_v_ra": 0.0841}

#beats.change_pars(model_constants)

# %% [markdown]
# https://pmc.ncbi.nlm.nih.gov/articles/PMC3148638/

# %%
model_constants = {"ratio_amref_lfw": 0.8, "ratio_amref_ww": 0.4, "ratio_amref_la": 0.46, "ratio_amref_ra": 0.34,
                   "ratio_v_lfw": 2.05, "ratio_v_ww": 1.25, "ratio_v_la": 0.1894, "ratio_v_ra": 0.0841}

beats.change_pars(model_constants)

# %%
#Run model and display convergence
#beats.clear_converged_sol()
beats.just_beat_it(print_solve=True)
# Out:
# Iteration 0:	6.60e-01 9.68e+00 3.77e-01 2.12e-01 1.63e-02 5.62e+00 5.07e-01 1.36e-01
# Iteration 1:	2.96e-01 7.48e-03 1.27e-01 2.18e-01 7.78e-02 1.84e-04 1.50e-01 1.36e-02
# Iteration 2:	3.71e-02 1.07e-03 3.36e-02 1.44e-01 3.37e-02 3.09e-03 1.64e-02 1.54e-04
# Iteration 3:	4.11e-03 1.70e-03 2.85e-02 8.03e-02 1.75e-02 1.93e-03 3.39e-02 2.18e-04
# Iteration 4:	1.40e-02 2.35e-03 2.56e-02 4.49e-02 9.99e-03 1.09e-03 2.58e-02 1.68e-03
# Iteration 5:	1.46e-02 2.18e-03 2.13e-02 2.69e-02 5.94e-03 6.12e-04 1.79e-02 2.48e-03
# Iteration 6:	1.21e-02 1.76e-03 1.67e-02 1.75e-02 3.47e-03 3.34e-04 1.24e-02 2.75e-03
# Iteration 7:	9.13e-03 1.32e-03 1.27e-02 1.21e-02 1.87e-03 1.66e-04 8.72e-03 2.72e-03
# Iteration 8:	6.44e-03 9.37e-04 9.30e-03 8.64e-03 8.07e-04 6.27e-05 6.16e-03 2.55e-03
# Steady-state circulation established

# %%
# Import plotting functions
import monarch.metamorphoses as meta

# Plot LV pressure-volume loop
meta.pv_loop(beats, compartments=("LV", "RV"))

# %%
from IPython.display import display
print(beats.outputs.RVEDP)
print(beats.outputs.LVEDP)
print(beats.outputs.ESWthSw)
print(beats.outputs.EDWthSw)
# Out:
# 0    9.515334
# Name: RVEDP, dtype: float64
# 0    11.653557
# Name: LVEDP, dtype: float64
# 0    1.660721
# Name: ESWthSw, dtype: float64
# 0    1.400493
# Name: EDWthSw, dtype: float64

# %% [markdown]
# #### Baseline
# CHAMELEON's Camouflage class is expecting a Pandas dataframe with all information for each output variable, which we set up here. We need `mu` (mean) and `sigma` (standard deviation), and optional the lower and upper limits labeled as `min` and `max`, resp. The time point of needs to be specified by `_label`, for a non-growth simulation this can be `_baseline` and/or `_acute`. We provide a utility function to convert the data to this format, and save it as a .csv file for documentation.

# %%
from chameleon.utils import convert_data
import pandas as pd

roi_baseline = ["RVEDV", "RVESV", "RVEDP", "RVESP","dpdt_max_rv","dpdt_min_rv"]


data_baseline = pd.read_csv("demo_monarch/data/data_baseline_P21_Hx_M.csv",index_col=0)
data_baseline
# Out:
#          mu_baseline  sigma_baseline       min       max
# RVEDV         0.0449          0.0133     0.025     0.070
# RVESV         0.0187          0.0081     0.005     0.035
# RVEDP         3.9000          1.0000     0.000    30.000
# RVESP        39.3000          6.3000    20.000    60.000
# RVMaxdP    2003.0000        570.0000  1000.000  3000.000
# RVMindP   -1446.0000        402.0000 -2200.000  -800.000
# EDWthSw       1.0900          0.0600     0.800     1.500
# ESWthSw       2.2600          0.0800     1.500     2.600

# %% [markdown]
# ## Global sensitivity analysis
# Before running the BHM, it is good practice to perform a sensitivity analysis. This can help you identify parameters or readouts that are irrelevant to the fitting process, and thus can be excluded from the fitting process and set constant. We will use the SALib package to perform a Sobol sensitivity analysis. In most models, performing a global sensitivity analysis is computationally expensive, so here take advantage of the low computational cost of the emulators to perform the analysis.
#
# First, decide what parameters to fit and what their expected ranges are, and compile them in a list of dictionaries (one for each parameter). It is crucial that the labels match (case-insensitive) the label names in MONARCH's change_pars function. A list of the supported parameters can be called using `monarch.utils.list_change_pars`.

# %%
pars = {
        "AmRefLfw": {"limits": [50, 100]},
        "AmRefRfw": {"limits": [70, 120]},
        "AmRefSw": {"limits": [15, 55]},
        "VLfw": {"limits": [80, 130]},
        "VRfw": {"limits": [40, 80]},
        "VSw": {"limits": [30, 70]},
        "SBV": {"limits": [0.7, 1.20]},
        "Rvp": {"limits": [5, 15]},
        "Rcs": {"limits": [30, 80]},
        "Ras": {"limits": [450, 650]},
        "Rvs": {"limits": [5, 15]},
        "Rcp": {"limits": [5, 20]},
        "Rap": {"limits": [100, 250]},
        "Rav": {"limits": [10, 20]},
        "Cvp": {"limits": [3e-3, 5e-3]},
        "Cas": {"limits": [5e-4, 7e-4]},
        "Cap": {"limits": [3e-2, 5e-2]},
        "Cvs": {"limits": [6e-3, 8e-3]},
        "sfact": {"limits": [0.01, 0.2]},
        "SAct": {"limits": [0.01, 0.2]},
    }

# %% [markdown]
# Set up the Camouflage class, making sure to run sufficient simulations to properly train the emulators. Similarly, use enough emulation points to get a good estimate of the Sobol indices. A minimum of `n_emu0` = $2^{11}$ = 2048 is generally recommended in the literature for this, so we go one order higher ($2^{12}$) just to be sure.

# %%
from chameleon import Camouflage

# Set up directories to store results
sense_dir = main_dir / "sensitivity"

# Setting up the wave class
wave = Camouflage(0, sense_dir, 5.0, pars, data_baseline, nroy=None, n_sim=2**8,
                  clear_log=True, n_emu0=2**12, n_emu_min=2**12)
# Out:
# -----------
# Parameters:
# -----------
# - AmRefLfw: [50.0 - 100.0]
# - AmRefRfw: [70.0 - 120.0]
# - AmRefSw: [15.0 - 55.0]
# - VLfw: [80.0 - 130.0]
# - VRfw: [40.0 - 80.0]
# - VSw: [30.0 - 70.0]
# - SBV: [0.7 - 1.2]
# - Rvp: [5.0 - 15.0]
# - Rcs: [30.0 - 80.0]
# - Ras: [450.0 - 650.0]
# - Rvs: [5.0 - 15.0]
# - Rcp: [5.0 - 20.0]
# - Rap: [100.0 - 250.0]
# - Rav: [10.0 - 20.0]
# - Cvp: [0.003 - 0.005]
# - Cas: [0.0005 - 0.0007]
# - Cap: [0.03 - 0.05]
# - Cvs: [0.006 - 0.008]
# - sfact: [0.01 - 0.2]
# - SAct: [0.01 - 0.2]
#
#
# -------------
# Observations:
# -------------
# - RVEDV: 0.0449 ± 0.0133
# - RVESV: 0.0187 ± 0.0081
# - RVEDP: 3.9 ± 1.0
# - RVESP: 39.3 ± 6.3
# - RVMaxdP: 2003.0 ± 570.0
# - RVMindP: -1446.0 ± 402.0
# - EDWthSw: 1.09 ± 0.06
# - ESWthSw: 2.26 ± 0.08
#
#
# -------------
# Constants:
# -------------
# None specified
#
#
#
# ------
# Wave 1
# ------
# Generated emulation point cloud with 4096 points

# %% [markdown]
# Now we will run model simulations to train the emulators. Depending on your computer, this may take several minutes. The results will be stored in the `sense_dir` / "Wave 1" directory. In contrast to the simple example in the sister notebook *simple_model*, we will need more advanced functions to run the simulations with each selected parameter set, and to obtain the output results. We will therefore included a module named `monarch_utils` that contains these functions, wrapped together in a function called `run_forest_run`. This function will run the simulations, store the results in `wave.sim_dir` (Default name "Wave #" / "sims"), and return the output results in a format that can be used by the Camouflage class.
#
# >Important: you can create your own version of the `monarch_utils` module to run any model of your choice, as long as it returns `x_sim` and `y_sim` in the correct format, i.e. numpy arrays with each row representing a parameter set and each column representing a different output variable, in the same order as `wave.x_names`.
#
# Note that when running the models with the cell below, several models will not converge, throwing warning. This is expected since we are running the model with a very broad parameter space, some of which result in unrealistic and unstable solutions. This is not a problem, since the implausible parameter sets will be filtered out in the BHM process later. Running the cel will take several seconds-minutes, depending on your computer. You can set `run_sims` to false if rerunning this cell/notebook to save time.

# %%
import chameleon.monarch_utils as monarch_utils

# Run simulations for all parameter sets in current wave set x to train the emulators
wave.x_sim, wave.y_sim, _ = monarch_utils.run_forest_run(wave, input_vo, [], run_sims=run_sims,
                                                              log_file=wave.log_file)
# Out:
# Running 256 model simulations...
# 256 simulations completed in 50.27 seconds
# 256 Simulations reached convergence
# 219 Simulations added to training data

# %% [markdown]
# Use the wrapper function to run the Sobol sensitivity analysis. This will take a while, depending on your computer.

# %%
# Wrapper to run gpe_training_validation and sobol_sensitivity
wave.surf_sensitivity()
# Out:
# Performing sensitivity analysis...
# Emulating 4096 points...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[115], line 2
#       1 # Wrapper to run gpe_training_validation and sobol_sensitivity
# ----> 2 wave.surf_sensitivity()
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\chameleon\camouflage.py:190, in Camouflage.surf_sensitivity(self, export_csv, export_pickle, print_summary, pickle_name)
#     187 """Wrapper function to run all the functions required for global sensitivity. Exports wave as pickle"""
#     189 self.gpe_training_validation(print_summary=print_summary)
# --> 190 self.sobol_sensitivity()
#     191 if export_csv:
#     192     self.gpe_export()
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\chameleon\camouflage.py:1135, in Camouflage.sobol_sensitivity(self, n_samples)
#    1133 x_emu, y_emu, y_emu_variance = np.copy(self.x_emu), np.copy(self.y_emu), np.copy(self.y_emu_variance)
#    1134 self.x_emu = x
# -> 1135 self.gpe_emulate()
#    1137 # Analyze
#    1138 self.sobol_indices = [sobol.analyze(self.sobol_problem, y) for y in self.y_emu.T]
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\chameleon\camouflage.py:581, in Camouflage.gpe_emulate(self, print_log)
#     579 # Predict mean and variance
#     580 with torch.no_grad():
# --> 581     observed_pred = likelihood(gpe_model(x_emu.double()))
#     582     self.y_emu[:, i_y] = observed_pred.mean.numpy()
#     583     self.y_emu_variance[:, i_y] = observed_pred.variance.numpy()
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\gpytorch\models\exact_gp.py:345, in ExactGP.__call__(self, *args, **kwargs)
#     340 # Make the prediction
#     341 with settings.cg_tolerance(settings.eval_cg_tolerance.value()):
#     342     (
#     343         predictive_mean,
#     344         predictive_covar,
# --> 345     ) = self.prediction_strategy.exact_prediction(full_mean, full_covar)
#     347 # Reshape predictive mean to match the appropriate event shape
#     348 predictive_mean = predictive_mean.view(*batch_shape, *test_shape).contiguous()
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\gpytorch\models\exact_prediction_strategies.py:324, in DefaultPredictionStrategy.exact_prediction(self, joint_mean, joint_covar)
#     320     test_test_covar = joint_covar[..., self.num_train :, self.num_train :]
#     321     test_train_covar = joint_covar[..., self.num_train :, : self.num_train]
#     323 return (
# --> 324     self.exact_predictive_mean(test_mean, test_train_covar),
#     325     self.exact_predictive_covar(test_test_covar, test_train_covar),
#     326 )
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\gpytorch\models\exact_prediction_strategies.py:349, in DefaultPredictionStrategy.exact_predictive_mean(self, test_mean, test_train_covar)
#     347 nan_policy = settings.observation_nan_policy.value()
#     348 if nan_policy == "ignore":
# --> 349     res = (test_train_covar @ mean_cache.unsqueeze(-1)).squeeze(-1)
#     350 elif nan_policy == "mask":
#     351     # Restrict train dimension to observed values
#     352     observed = settings.observation_nan_policy._get_observed(mean_cache, torch.Size((mean_cache.shape[-1],)))
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\linear_operator\operators\_linear_operator.py:2905, in LinearOperator.__matmul__(self, other)
#    2899 def __matmul__(
#    2900     self: Float[LinearOperator, "*batch M N"],
#    2901     other: Union[
#    2902         Float[torch.Tensor, "*batch2 N D"], Float[torch.Tensor, "N"], Float[LinearOperator, "*batch2 N D"]
#    2903     ],
#    2904 ) -> Union[Float[torch.Tensor, "... M D"], Float[torch.Tensor, "... M"], Float[LinearOperator, "... M D"]]:
# -> 2905     return self.matmul(other)
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\linear_operator\operators\_linear_operator.py:1839, in LinearOperator.matmul(self, other)
#    1835     from linear_operator.operators.matmul_linear_operator import MatmulLinearOperator
#    1837     return MatmulLinearOperator(self, other)
# -> 1839 return Matmul.apply(self.representation_tree(), other, *self.representation())
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\gpytorch\lazy\lazy_evaluated_kernel_tensor.py:406, in LazyEvaluatedKernelTensor.representation_tree(self)
#     402     return super().representation_tree()
#     403 # Otherwise, we'll evaluate the kernel (or at least its LinearOperator representation) and use its
#     404 # representation
#     405 else:
# --> 406     return self.evaluate_kernel().representation_tree()
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\gpytorch\utils\memoize.py:59, in _cached.<locals>.g(self, *args, **kwargs)
#      57 kwargs_pkl = pickle.dumps(kwargs)
#      58 if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59     return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60 return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\gpytorch\lazy\lazy_evaluated_kernel_tensor.py:25, in recall_grad_state.<locals>.wrapped(self, *args, **kwargs)
#      22 @functools.wraps(method)
#      23 def wrapped(self, *args, **kwargs):
#      24     with torch.set_grad_enabled(self._is_grad_enabled):
# ---> 25         output = method(self, *args, **kwargs)
#      26     return output
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\gpytorch\lazy\lazy_evaluated_kernel_tensor.py:355, in LazyEvaluatedKernelTensor.evaluate_kernel(self)
#     353     temp_active_dims = self.kernel.active_dims
#     354     self.kernel.active_dims = None
# --> 355     res = self.kernel(
#     356         x1,
#     357         x2,
#     358         diag=False,
#     359         last_dim_is_batch=self.last_dim_is_batch,
#     360         **self.params,
#     361     )
#     362     self.kernel.active_dims = temp_active_dims
#     364 # Check the size of the output
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\gpytorch\kernels\kernel.py:539, in Kernel.__call__(self, x1, x2, diag, last_dim_is_batch, **params)
#     536     res = LazyEvaluatedKernelTensor(x1_, x2_, kernel=self, last_dim_is_batch=last_dim_is_batch, **params)
#     537 else:
#     538     res = to_linear_operator(
# --> 539         super(Kernel, self).__call__(x1_, x2_, last_dim_is_batch=last_dim_is_batch, **params)
#     540     )
#     541 return res
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\gpytorch\module.py:82, in Module.__call__(self, *inputs, **kwargs)
#      81 def __call__(self, *inputs, **kwargs) -> Union[Tensor, Distribution, LinearOperator]:
# ---> 82     outputs = self.forward(*inputs, **kwargs)
#      83     if isinstance(outputs, list):
#      84         return [_validate_module_outputs(output) for output in outputs]
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\gpytorch\kernels\scale_kernel.py:118, in ScaleKernel.forward(self, x1, x2, last_dim_is_batch, diag, **params)
#     116 else:
#     117     outputscales = outputscales.view(*outputscales.shape, 1, 1)
# --> 118     return orig_output.mul(outputscales)
#
# KeyboardInterrupt:
# The kernel failed to start as a dll could not be loaded.
#
# Click <a href='https://aka.ms/kernelFailuresDllLoad'>here</a> for more info.

# %% [markdown]
# Now we plot the results of the global sensitivity analysis.

# %%
from chameleon import TrueColors

# Initialize TrueColors class
camo = TrueColors(sense_dir)

camo.plot_sensitivity_matrix(show_fig=True)
camo.plot_sensitivity_total(show_bar=True, cutoff=0.95)

# %% [markdown]
# Note that the sensitivity analysis shows that the parameter `c3` is not sensitive to any of the outputs. We will therefore exclude this parameter from the fitting process. `S_act` is on the brink of being excluded too, but we will keep it in for now.

# %% [markdown]
# # Remove from the pars dictionary
# if "Cvs" in pars:
#     pars.pop("Cvs")
#
# if "Cvp" in pars:
#     pars.pop("Cvp")
#
# if "Cas" in pars:
#     pars.pop("Cas")
#
# if "Rav" in pars:
#     pars.pop("Rav")
#
# if "Rap" in pars:
#     pars.pop("Rap")
#
# if "Rcp" in pars:
#     pars.pop("Rcp")
#
# print(pars)

# %%
pars = {
        "AmRefRfw": {"limits": [70, 120]},
        "VRfw": {"limits": [40, 80]},
        "SBV": {"limits": [0.7, 1.20]},
        "Rap": {"limits": [5, 20]},
        "Cap": {"limits": [3e-2, 5e-2]},
        "sf_act": {"limits": [0.01, 0.2]},
    }

# %% [markdown]
# Constants set geometric relationships based on RV

# %%
if "AmRefLfw" in pars: 
    pars.pop("AmRefLfw")

if "AmRefSw" in pars: 
    pars.pop("AmRefSw")

if "VLfw" in pars: 
    pars.pop("VLfw")

if "VSw" in pars: 
    pars.pop("VSw")

print(pars)
# Out:
# {'AmRefRfw': {'limits': [70, 120]}, 'VRfw': {'limits': [40, 80]}, 'SBV': {'limits': [0.7, 1.2]}, 'Rap': {'limits': [5, 20]}, 'Cap': {'limits': [0.03, 0.05]}, 'sf_act': {'limits': [0.01, 0.2]}}

# %% [markdown]
# ## Calibrating the baseline model
# ### Run calibration
# First, we store the true values of the parameters in a csv file to record and compare with the fitted values later.

# %%
# Reinitialize the model to clear growth results
beats = Hatch(input_vo)

# Add target values to parameter dictionary
for i, key in enumerate(pars.keys()):
    pars[key]["target"] = beats.get_pars([key])[key]
# Out:
# {'AmRefRfw': np.int64(90)}
# {'VRfw': np.int64(62)}
# {'SBV': 0.81}
# {'Rap': 180}
# {'Cap': 0.007}
# Parameter sf_act not found in model
# {'sf_act': nan}

# %% [markdown]
# We now run the entire BHM process, see the `simple_model` notebook for more details on this code fragment. Running this will take several minutes, depending on your computer. By default, we will utilize all but one CPUs on your computer. Note that, just like in the sensitivity analysis, many simulation in the early waves will crash because some very unrealistic parameter sets are included, but in later waves the model will behave much better since only non-implausible parameters sets are retained.

# %% [markdown]
#     # Initialize wave
#     wave = Camouflage(i_wave, baseline_dir, wave_threshold, pars, data_baseline, nroy=nroy, clear_log=(i_wave == 0),
#                 constants=model_constants, n_emu0=2**18, n_emu_min=100000)
#
#     # Run simulations for all parameter sets in current wave set
#     wave.x_sim, wave.y_sim, sim_dirs = monarch_utils.run_forest_run(wave, input_vo, sim_dirs, constants=model_constants,
#                                                                   log_file=wave.log_file, run_sims=run_sims)

# %%
# Storage directory
baseline_dir = main_dir / "baseline"

# Initialize wave index
i_wave = 0
nroy = None
not_flooded = True
sim_dirs = []

# Start history matching until convergence is reached
while not_flooded:

    # Set wave threshold: start with 5.0 and reduce incrementally with steps of 0.5 until 2.0 # can make 1/3 
    wave_threshold = max(5 - 1*i_wave, 2)
    
    # Initialize wave    
    wave = Camouflage(i_wave, baseline_dir, wave_threshold, pars, data_baseline, nroy=nroy, clear_log=(i_wave == 0), 
                constants=model_constants, n_emu0=2**18, n_emu_min=100000)

    # Run simulations for all parameter sets in current wave set
    wave.x_sim, wave.y_sim, sim_dirs = monarch_utils.run_forest_run(wave, input_vo, sim_dirs, constants=model_constants, 
                                                                  log_file=wave.log_file, run_sims=run_sims)

    # Run wave: train/validate emulators, emulate, calculate implausibility, find NROY
    wave.surf()

    # Check for convergence, store NROY from this wave as NROY for the next wave and update counter
    not_flooded = wave.is_flooded(i_wave, min_waves=4, max_waves=10)
    nroy = wave.nroy
    i_wave += 0.5
# Out:
# -----------
# Parameters:
# -----------
# - AmRefRfw: [70.0 - 120.0]
# - VRfw: [40.0 - 80.0]
# - SBV: [0.7 - 1.2]
# - Rap: [5.0 - 20.0]
# - Cap: [0.03 - 0.05]
# - sf_act: [0.01 - 0.2]
#
#
# -------------
# Observations:
# -------------
# - RVEDV: 0.0449 ± 0.0133
# - RVESV: 0.0187 ± 0.0081
# - RVEDP: 3.9 ± 1.0
# - RVESP: 39.3 ± 6.3
# - RVMaxdP: 2003.0 ± 570.0
# - RVMindP: -1446.0 ± 402.0
# - EDWthSw: 1.09 ± 0.06
# - ESWthSw: 2.26 ± 0.08
#
#
# -------------
# Constants:
# -------------
# - ratio_amref_lfw: 0.8
# - ratio_amref_ww: 0.4
# - ratio_amref_la: 0.46
# - ratio_amref_ra: 0.34
# - ratio_v_lfw: 2.05
# - ratio_v_ww: 1.25
# - ratio_v_la: 0.1894
# - ratio_v_ra: 0.0841
#
#
# -------------
# Parameter ground truth values:
# -------------
# - AmRefRfw: 90.0
# - VRfw: 62.0
# - SBV: 0.81
# - Rap: 180.0
# - Cap: 0.007
# - sf_act: nan
#
#
# ------
# Wave 1
# ------
# Generated emulation point cloud with 262144 points
# Running 128 model simulations...
# 128 simulations completed in 62.56 seconds
# 128 Simulations reached convergence
# 109 Simulations added to training data
# Emulating 262144 points...
# Emulation completed in 3.15 seconds
# 0 points remaining in NROY region (0.0% of original space)
# ESWthSw is the most implausible output (97.68% of all points)
# 0 points remaining in NROY region after limits check
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 25
#      21 wave.x_sim, wave.y_sim, sim_dirs = monarch_utils.run_forest_run(wave, input_vo, sim_dirs, constants=model_constants,
#      22                                                               log_file=wave.log_file, run_sims=run_sims)
#      24 # Run wave: train/validate emulators, emulate, calculate implausibility, find NROY
# ---> 25 wave.surf()
#      27 # Check for convergence, store NROY from this wave as NROY for the next wave and update counter
#      28 not_flooded = wave.is_flooded(i_wave, min_waves=4, max_waves=10)
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\chameleon\camouflage.py:177, in Camouflage.surf(self, sensitivity, export_csv, export_pickle, print_summary, pickle_name)
#     175 if self.y_lims is not None:
#     176     self.remove_non_physiological()
# --> 177 self.draw_posterior()
#     179 if sensitivity:
#     180     self.sobol_sensitivity()
#
# File c:\Users\salla\miniconda3\envs\chameleon\Lib\site-packages\chameleon\camouflage.py:970, in Camouflage.draw_posterior(self, nroy, n_samples)
#     967     n_samples = self.n_posterior
#     969 # Randomly draw n_sim points from the NROY region
# --> 970 idx = np.random.randint(nroy.shape[0], size=n_samples)
#     971 self.x_posterior = nroy[idx, :]
#
# File numpy/random/mtrand.pyx:794, in numpy.random.mtrand.RandomState.randint()
#
# File numpy/random/_bounded_integers.pyx:1425, in numpy.random._bounded_integers._rand_int32()
#
# ValueError: high <= 0

# %%
# Storage directory
baseline_dir = main_dir / "baseline"

# Initialize wave index
i_wave = 0
nroy = None
not_flooded = True
sim_dirs = []

# Start history matching until convergence is reached
while not_flooded:

    # Set wave threshold: start with 5.0 and reduce incrementally with steps of 0.5 until 2.0
    wave_threshold = max(5 - 1*i_wave, 2)
    
    # Initialize wave    
    wave = Camouflage(i_wave, baseline_dir, wave_threshold, pars, data_baseline, nroy=nroy, clear_log=(i_wave == 0), 
                constants=model_constants, n_emu0=2**18, n_emu_min=100000)

    # Run simulations for all parameter sets in current wave set
    wave.x_sim, wave.y_sim, sim_dirs = monarch_utils.run_forest_run(wave, input_vo, sim_dirs, constants=model_constants, 
                                                                  log_file=wave.log_file, run_sims=run_sims)

    # Run wave: train/validate emulators, emulate, calculate implausibility, find NROY
    wave.surf()

    # Check for convergence, store NROY from this wave as NROY for the next wave and update counter
    not_flooded = wave.is_flooded(i_wave, min_waves=4, max_waves=10)
    nroy = wave.nroy
    i_wave += 1

# %% [markdown]
# ### Analyzing the results
# Run and plot simulations using a randomly selected subset of the posterior distribution. Compare these results with the simulation results after we just ran the single wave with implausibility criterion of 5.0 to see the vast improvement.

# %%
# Run simulations for all parameter sets in current wave set
wave.draw_posterior()
wave.x_posterior, wave.y_posterior, _ = monarch_utils.run_forest_run(wave, input_vo, [],  constants=model_constants, 
                                                         log_file=wave.log_file, v_ticks=(0,.05), show_hemo=True, posterior=True,)

# Save the wave again to store the posterior results for plotting purposes
wave.pickle_wave()

# %% [markdown]
# Note how nicely the simulations are centered around the mean values we were trying to match. We can compare it better to the data using the TrueColors class. Start by comparing the posterior metrics to the data:

# %%
from chameleon import TrueColors

colors = TrueColors(baseline_dir)

# Plot the convergence of the implausibility
colors.plot_nroy_data(show_box=True)

# %% [markdown]
# Next, inspect the final NROY region to inspect if all parameters are uniquely fitted, and if the mean of the matched distribution is close to the true values in this synthetic case. This plot is time-consuming to generate, so we here run it with a subset of 5000 randomly chosen parameter sets.

# %%
colors.plot_nroy_x(n_samples=5000, show_fig=True)

# %% [markdown]
# Note how the calibrated parameter distributions are unimodal and nicely centered around the ground truth value. Run all plots, this will be time-consuming–in fact, it is slower than running BHM itself! The plots are saved in the *results* subdirectory.

# %%
colors.roll(nroy_full=False)

# %% [markdown]
# ## References
# [1] Jones, C. E. & Oomen, P. J. A. Synergistic Biophysics and Machine Learning Modeling to Rapidly Predict Cardiac Growth Probability. bioRxiv 2024.07.17.603959 (2024) doi:10.1101/2024.07.17.603959.
